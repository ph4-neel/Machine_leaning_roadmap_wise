# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 289          290         1       3                 Connolly, Miss. Kate
# 738          739         0       3                   Ivanoff, Mr. Kanio
# 213          214         0       2          Givard, Mr. Hans Kristensen
# 488          489         0       3        Somerton, Mr. Francis William
# 242          243         0       2      Coleridge, Mr. Reginald Charles
# 772          773         0       2                    Mack, Mrs. (Mary)
# 305          306         1       1       Allison, Master. Hudson Trevor
# 54            55         0       1       Ostby, Mr. Engelhart Cornelius
# 444          445         1       3    Johannesen-Bratthammer, Mr. Bernt
# 647          648         1       1  Simonius-Blumer, Col. Oberst Alfons
#
#         Sex    Age  SibSp  Parch       Ticket      Fare    Cabin Embarked
# 289  female  22.00      0      0       370373    7.7500      NaN        Q
# 738    male    NaN      0      0       349201    7.8958      NaN        S
# 213    male  30.00      0      0       250646   13.0000      NaN        S
# 488    male  30.00      0      0   A.5. 18509    8.0500      NaN        S
# 242    male  29.00      0      0  W./C. 14263   10.5000      NaN        S
# 772  female  57.00      0      0  S.O./P.P. 3   10.5000      E77        S
# 305    male   0.92      1      2       113781  151.5500  C22 C26        S
# 54     male  65.00      0      1       113509   61.9792      B30        C
# 444    male    NaN      0      0        65306    8.1125      NaN        S
# 647    male  56.00      0      0        13213   35.5000      A26        C

# %%
import seaborn as sns

# %% [markdown]
# ## Categorical Data

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# ## Numerical Data

# %%
plt.hist(df['Age'])
plt.show()

# %%
sns.distplot(df['Age'])
plt.show()
# Out:
# C:\Users\91906\AppData\Local\Temp\ipykernel_106392\1599895865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.boxplot(df['Survived'])
# Out:
# <Axes: >
